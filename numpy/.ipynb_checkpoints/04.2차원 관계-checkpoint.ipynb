# %% [markdown]
# -교재 3장 정리(누구나 파이썬 통계분석)

# %% [markdown]
# #### 2차원 데이터의 정리
#
# ##### 두 데이터 사이의 관계를 나태는 지표

# %%
import numpy as np
import pandas as pd

# %precision 3
pd.set_option('precision', 3)

# %%
df = pd.read_csv('C:/Users\Administrator/Desktop/coding/python/muticam/jupyter note/data/data/ch2_scores_em.csv',
                 index_col='student number')
# df의 처음 5행을 표시
df.head()
# Out:
#                 english  mathematics
# student number
# 1                    42           65
# 2                    69           80
# 3                    56           63
# 4                    41           63
# 5                    57           76

# %%
en_scores = np.array(df['english'])[:10]
ma_scores = np.array(df['mathematics'])[:10]

scores_df = pd.DataFrame({'english':en_scores,
                          'mathematics':ma_scores},
                         index=pd.Index(['A', 'B', 'C', 'D', 'E',
                                         'F', 'G', 'H', 'I', 'J'],
                                        name='student'))
scores_df
# Out:
#          english  mathematics
# student
# A             42           65
# B             69           80
# C             56           63
# D             41           63
# E             57           76
# F             48           60
# G             65           81
# H             49           66
# I             65           78
# J             58           82

# %% [markdown]
# - 10명의 학생의 영어점수와 수학점수의 관계 확인을 scatter 그래프를 그림

# %% [markdown]
# plt.xticks([40,45,50,55,60,65,70])
# plt.xlabel('english score')
# plt.ylabel('mathematics score')
# plt.yticks([60,65,70,75,80,85])

# %% [markdown]
# ### 共分散(공분산)
#
# - 보통 Cov 라고 표현한다. 공분산은 두 개 또는 그 이상의 랜덤 변수에 대한 의존성을 의미
#
# - 직사각형의 가로길이는 영어 점수의 편차, 세로는 수학 점수의 편차
# - 공분산은 면적, 음의 면적도 가능(음의 상관)
# - 아래 그림에서 H와 E의 면적은 양의 값(양의 상관관계),  C는 음의 값(음의 상관관계)

# %% [markdown]
# ![%EA%B3%B5%EB%B6%84%EC%82%B0.jpg](attachment:%EA%B3%B5%EB%B6%84%EC%82%B0.jpg)

# %%
# 각 과목의 편차 및 과목간 공분산

summary_df = scores_df.copy()
summary_df['english_deviation'] =\
    summary_df['english'] - summary_df['english'].mean()
summary_df['mathematics_deviation'] =\
    summary_df['mathematics'] - summary_df['mathematics'].mean()
summary_df['product of deviations'] =\
    summary_df['english_deviation'] * summary_df['mathematics_deviation']
summary_df
# Out:
#          english  mathematics  english_deviation  mathematics_deviation  \
# student
# A             42           65              -13.0                   -6.4
# B             69           80               14.0                    8.6
# C             56           63                1.0                   -8.4
# D             41           63              -14.0                   -8.4
# E             57           76                2.0                    4.6
# F             48           60               -7.0                  -11.4
# G             65           81               10.0                    9.6
# H             49           66               -6.0                   -5.4
# I             65           78               10.0                    6.6
# J             58           82                3.0                   10.6
#
#          product of deviations
# student
# A                         83.2
# B                        120.4
# C                         -8.4
# ...

# %% [markdown]
# ### 상관계수
#
#
# - 공분산의 단위는 직감적으로 이해하기 어려우므로, 단위에 의존하지 않는 상관을 나타내는 지표
#     - 시험 점수간의 공분산 (점수X점수), 키와 점수간의 공분산 (cm X 점수)
# - 상관계수는 공분산을 각 데이터의 표준편차로 나누어 단위에 의존하지 않음

# %% [markdown]
# ![%EC%83%81%EA%B4%80%EA%B3%84%EC%88%98%EC%88%98%EC%8B%9D.PNG](attachment:%EC%83%81%EA%B4%80%EA%B3%84%EC%88%98%EC%88%98%EC%8B%9D.PNG)

# %% [markdown]
# #### 상관계수 함수(np.corrcoef(x,y) / df.corr())

# %% [markdown]
# ![%EC%83%81%EA%B4%80%EA%B3%84%EC%88%98%EC%98%88%EC%8B%9C.jpg](attachment:%EC%83%81%EA%B4%80%EA%B3%84%EC%88%98%EC%98%88%EC%8B%9C.jpg)
