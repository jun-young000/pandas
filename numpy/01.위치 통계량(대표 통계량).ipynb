# %%
import numpy as np
from scipy.stats import *
import pandas as pd
import math

# Jupyter Notebook의 출력을 소수점 이하 3자리로 제한
# %precision 3
# Dataframe의 출력을 소수점 이하 3자리로 제한
pd.set_option('precision', 3)

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity="all"

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 데이터의 특징을 요약, 기술하는 통계량
# - 위치 통계량(measure of location)
#     - 데이터의 중심 위치를 나타내는 척도(대표값)
#     - 평균, 중위수, 절사평균, 최빈수 등
#
# - 변이 통계량(measure of dispersion)
#     - 데이터의 퍼짐,흩어진 정도를 나타내는 척도(산포도)
#     - 표준편차, 분산, 사분위간범위 등
#
# - 모양 통계량(measure of shape)
#     - 사분위수
#
#     - 왜도
#         - 중심 위치로부터 어느 한쪽으로 치우친(비대칭) 정도를 나타내는 척도
#     - 첨도
#         - 분포의 뾰족한 정도

# %% [markdown]
# # 위치 통계량(중심 경향성)

# %% [markdown]
# ![%ED%8F%89%EA%B7%A0.PNG](attachment:%ED%8F%89%EA%B7%A0.PNG)

# %% [markdown]
# ####  평균(mean)
# - 가장 많이 사용되는 대표값
#     - 모든 데이터의 합을 데이터의 개수로 나눈 값(산술평균)
#    ![](평균.png)
#
# - 특징
#     - 계산이 쉽고, 수학적으로 활용하기 편리하며 각 자료에 대해 유일한 값을 가짐
#     - 분산의 계산, 모수 추정, 가설검정 등 통계분석의 대표적인 통계량으로 널리 사용됨
#     - 데이터에 극단적인 값이 포함될 경우 평균이 왜곡되는 경향이 있음
#     - 이러한 경우, 대표 값으로 중앙값을 사용

# %% [markdown]
# #### 산술 평균 계산
# - 가장 널리 사용되는 평균으로 연속형 변수에 대해 사용
# - 다른 관측치에 비해 매우크거나 작은값에 크게 영향을받음

# %%
x=[1,2,3,4,5]
np.mean(x)
np.array(x).mean()
pd.Series(x).mean()
# Out:
# 3.0
# 3.0
# 3.000

# %%
# 이진 변수에 대한 평균- 이진값(0,1로 구성된 값)
# 이진 변수에 대한 산술 평균은 1의 비율과 같음


x=[1,0,0,0,1]
print(np.mean(x))
# Out:
# 0.4

# %%
df = pd.read_csv('C:/Users\Administrator/Desktop/coding/python/muticam/jupyter note/data/data/ch2_scores_em.csv',
                 index_col='student number')
# df의 처음 5행을 표시
df.head()
# Out:
#                 english  mathematics
# student number
# 1                    42           65
# 2                    69           80
# 3                    56           63
# 4                    41           63
# 5                    57           76

# %%
scores=np.array(df["english"])[:10]

# %%
scores_df = pd.DataFrame({'score':scores},
                         index=pd.Index(['A', 'B', 'C', 'D', 'E',
                                         'F', 'G', 'H', 'I', 'J'],
                                        name='student'))
scores_df
# Out:
#          score
# student
# A           42
# B           69
# C           56
# D           41
# E           57
# F           48
# G           65
# H           49
# I           65
# J           58

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
sum(scores)/len(scores)
np.mean(scores)
scores_df.mean()
# Out:
# 55.0
# 55.0
# score    55.0
# dtype: float64

# %% [markdown]
# #### 기하평균
# - n개의 양수 값을 모두 곱한 것의 n 제곱근
# - 성장률의 평균
# ![](기하평균.png)

# %% [markdown]
# ![%EA%B8%B0%ED%95%98%ED%8F%89%EA%B7%A0.PNG](attachment:%EA%B8%B0%ED%95%98%ED%8F%89%EA%B7%A0.PNG)

# %% [markdown]
# - 아래 year데이터는 어느 회사의 매출 증가율을 수집해 놓은 데이터임
#     - 1차년도에 200% , 2차년도에 800%, 3차년도에 300% 성장을 했다면 연평균 성장율은 어떻게 되는가?

# %%
year=[2,8,3]

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def multiply(arr):
    ans = 1
    for n in arr:
        if n == 0:
                return 0
        ans *= n
    return ans

# %% [markdown]
# ![image.png](attachment:image.png)
