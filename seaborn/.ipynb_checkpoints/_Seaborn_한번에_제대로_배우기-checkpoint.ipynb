# %% [markdown]
# # Seaborn 한번에 제대로 배우기

# %% [markdown]
# ## Seaborn 특징
#
# * 여러 변수 간의 관계를 검사하기 위한 데이터 집합 지향 API
# * 범주형 변수를 사용하여 관측치 또는 집계 통계량을 표시하기 위한 전문적인 지원
# * 일변량 또는 이변량 분포를 시각화하고 데이터의 부분 집합 간 비교하기 위한 옵션
# * 서로 다른 종류의 종속 변수에 대한 선형 회귀 모형의 자동 추정 및 표시
# * 복잡한 데이터셋의 전체 구조에 대한 편리한 보기
# * 복잡한 시각화를 쉽게 구축할 수 있는 다중 플롯 그리드 구조를 위한 높은 수준의 추상화
# * 여러 테마가 내장된 matplotlib 그림 스타일링 제어
# * 데이터의 패턴을 충실히 나타내는 색상 팔레트 선택 도구

# %%
import numpy as np
import pandas as pd
from scipy import stats
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style="whitegrid")

# %% [markdown]
# ## 산점도(Scatter Plot)

# %%
penguins=sns.load_dataset("penguins")

# %%
penguins
# Out:
#     species     island  bill_length_mm  ...  flipper_length_mm  body_mass_g     sex
# 0    Adelie  Torgersen            39.1  ...              181.0       3750.0    Male
# 1    Adelie  Torgersen            39.5  ...              186.0       3800.0  Female
# 2    Adelie  Torgersen            40.3  ...              195.0       3250.0  Female
# 3    Adelie  Torgersen             NaN  ...                NaN          NaN     NaN
# 4    Adelie  Torgersen            36.7  ...              193.0       3450.0  Female
# ..      ...        ...             ...  ...                ...          ...     ...
# 339  Gentoo     Biscoe             NaN  ...                NaN          NaN     NaN
# 340  Gentoo     Biscoe            46.8  ...              215.0       4850.0  Female
# 341  Gentoo     Biscoe            50.4  ...              222.0       5750.0    Male
# 342  Gentoo     Biscoe            45.2  ...              212.0       5200.0  Female
# 343  Gentoo     Biscoe            49.9  ...              213.0       5400.0    Male
#
# [344 rows x 7 columns]

# %%
sns.relplot(x="bill_length_mm", y="bill_depth_mm",data=penguins);

# %%
sns.relplot(x="flipper_length_mm", y="body_mass_g",data=penguins);

# %%
sns.relplot(x="bill_length_mm", y="bill_depth_mm",
            hue="bill_length_mm",data=penguins,);

# %%
sns.relplot(x="flipper_length_mm", y="body_mass_g",
          hue="species",data=penguins);

# hue 색상

# %%
sns.relplot(x="flipper_length_mm", y="body_mass_g",
          hue="species",style="island",data=penguins);

# %%
sns.relplot(x="flipper_length_mm", y="body_mass_g",
          hue="species",col="island",data=penguins);

# %%
sns.relplot(x="bill_length_mm", y="bill_depth_mm",
            hue="species",col="island",data=penguins);

# %%
sns.relplot(x="bill_length_mm", y="bill_depth_mm",
            hue="flipper_length_mm",data=penguins);

# %%
sns.relplot(x="bill_length_mm", y="bill_depth_mm",
            hue="body_mass_g",data=penguins);

# %%
sns.relplot(x="bill_length_mm", y="bill_depth_mm",
            hue="body_mass_g",size="body_mass_g",data=penguins);
# 구분 동그라미 크기 차이둠

# %%
sns.relplot(x="bill_length_mm", y="bill_depth_mm",
            hue="body_mass_g",size="body_mass_g",
            sizes=(10,100),data=penguins);
    # 구분 동그라미 크기 조절

# %% [markdown]
# ## 라인 플롯(Line Plot)

# %%
flights=sns.load_dataset("flights")

# %%
flights
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
sns.relplot(x="year",y="passengers",kind="line",data=flights)

# %%
dots=sns.load_dataset("dots")

# %%
dots
# Out:
#     align choice  time  coherence  firing_rate
# 0    dots     T1   -80        0.0    33.189967
# 1    dots     T1   -80        3.2    31.691726
# 2    dots     T1   -80        6.4    34.279840
# 3    dots     T1   -80       12.8    32.631874
# 4    dots     T1   -80       25.6    35.060487
# ..    ...    ...   ...        ...          ...
# 843  sacc     T2   300        3.2    33.281734
# 844  sacc     T2   300        6.4    27.583979
# 845  sacc     T2   300       12.8    28.511530
# 846  sacc     T2   300       25.6    27.009804
# 847  sacc     T2   300       51.2    30.959302
#
# [848 rows x 5 columns]

# %%
sns.relplot(x="time",y="firing_rate",kind="line",data=dots);
#95% 신뢰구간이 색칠되있는 부분이다.

# %%
sns.relplot(x="time",y="firing_rate",ci="sd",kind="line",data=dots);
#표준편차구간이 색칠됨

# %%
sns.relplot(x="time",y="firing_rate",ci=None, kind="line",data=dots);

# %%
sns.relplot(x="time",y="firing_rate",estimator=None,kind="line",data=dots);
# estimator 추정량

# %%
sns.relplot(x="time",y="firing_rate",hue="choice",kind="line",data=dots);
# hue 색상

# %%
sns.relplot(x="time",y="firing_rate",hue="align",kind="line",data=dots);

# %%
sns.relplot(x="time",y="firing_rate",
            hue="align",style="choice",
            kind="line",data=dots);

# %%
sns.relplot(x="time",y="firing_rate",
            hue="align",style="choice",
            dashes=False, markers=True,
            kind="line",data=dots);

  # dashes 줄표

# %%
sns.relplot(x="time",y="firing_rate",
            hue="align",style="choice",
            dashes=True, markers=True,
            kind="line",data=dots);

# %%
sns.relplot(x="time",y="firing_rate",
            hue="align",style="choice",
            dashes=True, markers=False,
            kind="line",data=dots);

# %%
sns.relplot(x="time",y="firing_rate",
            hue="align",col="choice",
            kind="line",data=dots);

# %%
sns.relplot(x="time",y="firing_rate",
            style="choice",
            kind="line",data=dots.query("align=='sacc'"));
# 특정 원하는 것만 가져오고 싶을때.

# %%
sns.relplot(x="time",y="firing_rate",
            hue="coherence",style="choice",
            kind="line",data=dots.query("align=='sacc'"));

# %%
sns.relplot(x="time",y="firing_rate",
            hue="coherence",col="choice",
            kind="line",data=dots.query("align=='sacc'"));

# %%
fmri=sns.load_dataset("fmri")

# %%
fmri
# Out:
#      subject  timepoint event    region    signal
# 0        s13         18  stim  parietal -0.017552
# 1         s5         14  stim  parietal -0.080883
# 2        s12         18  stim  parietal -0.081033
# 3        s11         18  stim  parietal -0.046134
# 4        s10         18  stim  parietal -0.037970
# ...      ...        ...   ...       ...       ...
# 1059      s0          8   cue   frontal  0.018165
# 1060     s13          7   cue   frontal -0.029130
# 1061     s12          7   cue   frontal -0.004939
# 1062     s11          7   cue   frontal -0.025367
# 1063      s0          0   cue  parietal -0.006899
#
# [1064 rows x 5 columns]

# %%
sns.relplot(x="timepoint",y="signal",
            kind="line",data=fmri);

# %%
sns.relplot(x="timepoint",y="signal",
            sort=False,kind="line",data=fmri);
# 보통은 자동정렬을 해주는데 이렇게 정렬옵션을 끄면..ㅡㅡ
# 즉 옵션끄지는 말자..

# %%
sns.relplot(x="timepoint",y="signal",
            style="region",size="event",        
            kind="line",data=fmri);

# %%
sns.relplot(x="timepoint",y="signal",
            hue="subject",
            style="region",size="event",        
            kind="line",data=fmri);
# 모든 데이터를 불러오는것이 마냥 좋은게 아니다..

# %%
palette=sns.cubehelix_palette(n_colors=14,light=0.8)
sns.relplot(x="timepoint",y="signal",
            hue="subject",col="region",size="event",        
            palette=palette,kind="line",data=fmri);
# 씨본의 장점이 색깔을 불러오기가 쉬움..

# %%
palette=sns.cubehelix_palette(n_colors=14,light=0.8)
sns.relplot(x="timepoint",y="signal",
            hue="subject",col="region",style="event",        
            palette=palette,kind="line",data=fmri);

# %%
palette=sns.cubehelix_palette(n_colors=14,light=0.8)
sns.relplot(x="timepoint",y="signal",
            hue="subject",col="region",style="event",        
            palette=palette,kind="line",data=fmri);
# 아까보다는 나으나 워낙 subject가 많아서 복잡해보임..어떻게 하지.

# %%
palette=sns.cubehelix_palette(n_colors=14,light=0.8)
sns.relplot(x="timepoint",y="signal",
            hue="subject",col="region",style="event",        
            palette=palette, kind="line",data=fmri.query("event=='cue'"));

# %%
sns.relplot(x="timepoint",y="signal",
            hue="subject",col="region",        
            palette=palette, kind="line",data=fmri.query("event=='cue'"));

# %%
sns.relplot(x="timepoint",y="signal",
            hue="subject",col="region",row="event",       
            palette=palette, kind="line",data=fmri);

# %%
sns.relplot(x="timepoint",y="signal",
            hue="event",style="event",
            col="subject",col_wrap=4,linewidth=3,        
            kind="line",data=fmri.query("region=='parietal'"));

# %%
tdf=pd.DataFrame(np.random.randn(40,4),
                 index=pd.date_range('2020-01-01',periods=40),
                 columns=['A','B','C','D'])

# %%
tdf
# Out:
#                    A         B         C         D
# 2020-01-01 -1.547053 -0.806290 -1.325559  1.907006
# 2020-01-02 -1.576264 -1.306346 -1.930201 -1.567619
# 2020-01-03 -1.301192  1.589457  0.556339  1.393069
# 2020-01-04  0.803544 -0.485244 -0.087054 -0.509660
# 2020-01-05  1.195000 -0.155376  0.923858  0.068828
# 2020-01-06 -0.168258 -0.161535  0.783819 -1.911535
# 2020-01-07  0.504952 -1.259235  0.473416 -0.448305
# 2020-01-08  0.884399  0.723464  1.639609  1.002720
# 2020-01-09 -0.180967 -0.496770  0.326216  0.087894
# 2020-01-10 -1.687093 -1.221335  0.361054 -0.898341
# 2020-01-11  0.467512  0.535083 -0.235886 -0.812089
# 2020-01-12 -0.011863 -0.013446  0.791875 -0.932420
# 2020-01-13 -1.272118  0.077781  1.057871 -1.434987
# 2020-01-14  1.208488  1.534355  0.366917 -0.565611
# 2020-01-15 -1.433388 -0.832247 -1.362092 -1.465289
# 2020-01-16  0.445657  1.447042  0.685428  0.996605
# 2020-01-17 -0.661218 -1.234545  0.138890  1.335100
# 2020-01-18 -1.301422  1.097046  0.320891 -1.738344
# 2020-01-19 -0.852641  0.535654 -1.001809 -0.626324
# 2020-01-20  0.373498 -1.018469 -1.482048  0.287821
# 2020-01-21  0.006156 -0.971255  1.270063 -1.963390
# 2020-01-22  1.953450 -0.160153 -0.393097  0.183352
# 2020-01-23  0.321861  0.125544  0.557227 -0.884002
# 2020-01-24 -0.259610 -1.407119  0.571059 -0.177384
# 2020-01-25 -0.491388  0.234377  0.692978  0.645681
# 2020-01-26 -0.441599 -1.373915  0.062778  0.375100
# 2020-01-27  1.781628 -0.917761  0.243297  0.998052
# 2020-01-28  0.614443  0.776671 -0.581045  0.224780
# 2020-01-29  0.721277 -1.864205  0.481060 -0.497102
# 2020-01-30  0.383371  0.415442 -0.370242  0.258442
# 2020-01-31  0.790522  1.007784 -0.409799 -2.029409
# 2020-02-01  0.400699  0.538698 -1.062660 -1.408876
# 2020-02-02 -1.600087  0.248145 -1.022232 -1.055605
# 2020-02-03 -1.315723 -0.991358 -0.695002 -0.443446
# 2020-02-04 -0.795264 -0.713217  1.692710  0.297047
# 2020-02-05 -0.842307 -0.064372  1.993413  1.448387
# 2020-02-06 -1.874161  1.307794 -1.259729  1.764171
# 2020-02-07  0.655912  0.266343  0.206424 -0.189640
# 2020-02-08  2.380920  1.122982  1.112465 -0.383649
# 2020-02-09 -0.535630 -0.462263  0.587721  1.745400

# %%
sns.relplot(kind='line',data=tdf);

# %%
# 가로 인덱스  오버랩되는 부분 수정이 필요
g=sns.relplot(kind='line',data=tdf)
g.fig.autofmt_xdate()

# %%
g=sns.relplot(kind='line',data=tdf['A'])
g.fig.autofmt_xdate()
# 데이터베이스니깐 이렇게 특정 컬럼만 불러오기 가능

# %% [markdown]
# ## 범주형 데이터(Categorical Data)

# %% [markdown]
# ### 범주형 산점도(Categorical scatterplots)
#
# * `stripplot()` (with `kind="strip"`; the default)
# * `swarmplot()` (with `kind="swarm"`)

# %%
sns.catplot(x="species", y="body_mass_g",data=penguins);

# %%
sns.catplot(x="species", y="body_mass_g",
           jitter=False,data=penguins);

# %%
# 여기서 생각해볼꺼리: 위 아래의 차이가 잇을까?
sns.relplot(x="species", y="body_mass_g",data=penguins);

# %%
sns.catplot(x="species", y="body_mass_g",
           kind='swarm',data=penguins);
          
# jitter는 어느정도 겹치지만 swarm은 아에 안겹치게 흐트려 놓음

# %%
sns.catplot(x="species", y="body_mass_g",
            hue='sex',
           kind='swarm',data=penguins);

# %%
sns.catplot(x="sex", y="body_mass_g",
            hue='species',
           kind='swarm',data=penguins);

# %%
sns.catplot(x="sex",y="body_mass_g",
            hue="species",kind="swarm",
            order=["FEMALE","MALE"], data=penguins);


# 왜 안나오지?

# %%
sns.catplot(x="body_mass_g",y="species",
            hue="island",kind="swarm",
            data=penguins);

# %%
sns.catplot(x="species",y="body_mass_g",
            hue="sex",col='island',
            kind="swarm",data=penguins);

# %%
sns.catplot(x="species",y="body_mass_g",
            hue="sex",col='island',aspect=0.7,
            kind="swarm",data=penguins);
# 간격을 좀 줄임

# %% [markdown]
# ### 범주형 분포도(Categorical distribution plots):
#
# * `boxplot()` (with `kind="box"`)
# * `boxenplot()` (with `kind="boxen"`)
# * `violinplot()` (with `kind="violin"`)

# %% [markdown]
# #### 박스 플롯(Box plots)

# %%
sns.catplot(x="species",y="body_mass_g",
            kind="box",data=penguins);

# %%
sns.catplot(x="species",y="body_mass_g",
            hue="sex",
            kind="box",data=penguins);

# %%
sns.catplot(x="species",y="body_mass_g",
            hue="sex",kind="box",
            dodge=False,data=penguins);

# %%
sns.catplot(x="species",y="body_mass_g",
            col="sex",kind="box",
            data=penguins);

# %%
sns.catplot(x="species",y="body_mass_g",
            row="sex",kind="box",
            data=penguins);
# 열이 아니라 행으로 !!

# %%
sns.catplot(x="species",y="body_mass_g",
            row="sex",kind="box",
            height=2,aspect=4,
            data=penguins);

# %%
sns.catplot(y="species",x="body_mass_g",
            row="sex",kind="box",
            height=2,aspect=4,
            data=penguins);

# %%
iris=sns.load_dataset("iris")
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
sns.catplot(kind="box",data=iris);
# x,y를 특별히 지정하지 않으면 자동으로

# %%
sns.catplot(kind="box",orient='h',
            data=iris);
# 위그래프 x,y변경

# %%
sns.catplot(x="species",y="sepal_length",
            kind="box",data=iris);

# %%
sns.catplot(x="petal_length",y="species",
            kind="box",data=iris);

# %% [markdown]
# #### 박슨 플롯(Boxen plots)

# %%
#박스보다는 조금더 자세한 정보를 불러올수 있다.
diamonds=sns.load_dataset("diamonds")
diamonds
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %%
sns.catplot(x='cut',y='price',
            kind='boxen',data=diamonds);

# %%
sns.catplot(x='color',y='price',
            kind='boxen',data=diamonds);

# %%
sns.catplot(x='color',y='price',
            kind='boxen',data=diamonds.sort_values("color"));

# %%
sns.catplot(x='clarity',y='price',
            kind='boxen',data=diamonds);

# %% [markdown]
# #### 바이올린 플롯(Violin plots)
#
# * `violinplot`: 커널 밀도 추정과 상자 도표 결합

# %%
penguins=sns.load_dataset("penguins")

# %%
penguins
# Out:
#     species     island  bill_length_mm  ...  flipper_length_mm  body_mass_g     sex
# 0    Adelie  Torgersen            39.1  ...              181.0       3750.0    Male
# 1    Adelie  Torgersen            39.5  ...              186.0       3800.0  Female
# 2    Adelie  Torgersen            40.3  ...              195.0       3250.0  Female
# 3    Adelie  Torgersen             NaN  ...                NaN          NaN     NaN
# 4    Adelie  Torgersen            36.7  ...              193.0       3450.0  Female
# ..      ...        ...             ...  ...                ...          ...     ...
# 339  Gentoo     Biscoe             NaN  ...                NaN          NaN     NaN
# 340  Gentoo     Biscoe            46.8  ...              215.0       4850.0  Female
# 341  Gentoo     Biscoe            50.4  ...              222.0       5750.0    Male
# 342  Gentoo     Biscoe            45.2  ...              212.0       5200.0  Female
# 343  Gentoo     Biscoe            49.9  ...              213.0       5400.0    Male
#
# [344 rows x 7 columns]

# %%
sns.catplot(x="species", y="body_mass_g",
            hue="sex",kind='violin',data=penguins);

# %%
sns.catplot(x="species", y="body_mass_g",
            hue="sex",kind='violin',
            bw=.15, cut=0 ,data=penguins);

# %%
sns.catplot(x="species", y="body_mass_g",
            hue="sex",kind='violin',
           split=True ,data=penguins);

# %%
sns.catplot(x="species", y="body_mass_g",
            hue="sex",kind='violin',
           inner="stick" ,split=True,
            data=penguins);

# %%
sns.catplot(x="species", y="body_mass_g",
           kind='violin',inner=None,data=penguins);

# %%
g=sns.catplot(x="species",y="body_mass_g",
           kind='violin',inner=None,data=penguins);

sns.swarmplot(x="species",y="body_mass_g",
              color="k",size=3,
              data=penguins, ax=g.ax);
# 바이올린 플롯안에 산점도 플롯도 집어넣을수 있다.

# %%
g=sns.catplot(
           kind='violin',data=iris);

# %%
g=sns.catplot(kind='violin',orient='h',data=iris);

# %%
g=sns.catplot(x='species', y='sepal_length',kind='violin',data=iris);

# %%
g=sns.catplot(x='petal_length', y='species',kind='violin',data=iris);

# %% [markdown]
# ### 범주형 추정치 도표(Categorical estimate plots)
#
# * `barplot()` (with `kind="bar"`)
# * `pointplot()` (with `kind="point"`)
# * `countplot()` (with `kind="count"`)

# %% [markdown]
# #### 막대 플롯(Bar plots)

# %%
mpg=sns.load_dataset("mpg")
mpg
# Out:
#       mpg  cylinders  ...  origin                       name
# 0    18.0          8  ...     usa  chevrolet chevelle malibu
# 1    15.0          8  ...     usa          buick skylark 320
# 2    18.0          8  ...     usa         plymouth satellite
# 3    16.0          8  ...     usa              amc rebel sst
# 4    17.0          8  ...     usa                ford torino
# ..    ...        ...  ...     ...                        ...
# 393  27.0          4  ...     usa            ford mustang gl
# 394  44.0          4  ...  europe                  vw pickup
# 395  32.0          4  ...     usa              dodge rampage
# 396  28.0          4  ...     usa                ford ranger
# 397  31.0          4  ...     usa                 chevy s-10
#
# [398 rows x 9 columns]

# %%
sns.catplot(x='origin', y='mpg', hue='cylinders', kind='bar');
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-197-77372e4616a9> in <module>()
# ----> 1 sns.catplot(x='origin', y='mpg', hue='cylinders', kind='bar');
#
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py in catplot(x, y, hue, data, row, col, col_wrap, estimator, ci, n_boot, units, seed, order, hue_order, row_order, col_order, kind, height, aspect, orient, color, palette, legend, legend_out, sharex, sharey, margin_titles, facet_kws, **kwargs)
#    3790     p = _CategoricalPlotter()
#    3791     p.require_numeric = plotter_class.require_numeric
# -> 3792     p.establish_variables(x_, y_, hue, data, orient, order, hue_order)
#    3793     if (
#    3794         order is not None
#
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py in establish_variables(self, x, y, hue, data, orient, order, hue_order, units)
#     151                 if isinstance(var, str):
#     152                     err = "Could not interpret input '{}'".format(var)
# --> 153                     raise ValueError(err)
#     154
#     155             # Figure out the plotting orientation
#
# ValueError: Could not interpret input 'origin'

# %% [markdown]
# #### 포인트 플롯(Point plots)
#
# * 축의 높이를 사용하여 추정값을 인코딩하여 점 추정값과 신뢰 구간 표시

# %% [markdown]
# #### 카운트 플롯(Count plots)

# %% [markdown]
# ## 분포 시각화(Distribution Visualization)

# %% [markdown]
# ### 일변량 분포(Univariate distributions)

# %% [markdown]
# #### 히스토그램(Histograms)

# %% [markdown]
# #### 커널 밀도 추정(Kernel density estimation)

# %% [markdown]
# ### 이변량 분포(Bivariate distributions)

# %% [markdown]
# #### 산점도(Scatterplots)
#
# * `jointplot`: 두 개의 변수 간의 이변량(또는 joint) 관계와 별도의 축에 각각의 일변량(또는 marginal) 분포가 모두 표시되는 다중 패널 플롯 생성

# %% [markdown]
# #### 육각 빈 플롯(Hexbin plots)

# %% [markdown]
# #### 커널 밀도 추정(Kernel density estimation)

# %% [markdown]
# ### 페어와이즈 관계 시각화(Visualizing pairwise relationships)

# %% [markdown]
# ### 히트맵(Heat Map) & 클러스터맵(Cluster Map)

# %% [markdown]
# ## 선형 관계 시각화(Visualizing linear relationships)

# %% [markdown]
# ### 선형 회귀 모델 시각화 함수

# %% [markdown]
# ### 다른 종류의 모델

# %% [markdown]
# ### 다른 상황의 회귀

# %% [markdown]
# ## 구조화된 다중 플롯 그리드

# %% [markdown]
# ### FacetGrid

# %% [markdown]
# ### 커스텀 함수(Custom functions)

# %% [markdown]
# ### 페어와이즈 데이터 관계(pairwise data relationships)

# %% [markdown]
# ## 그림 미학 제어

# %% [markdown]
# ### Seaborn 스타일

# %% [markdown]
# ### 축 스핀 제거

# %% [markdown]
# ### 스타일 임시 설정

# %% [markdown]
# ### 스타일 요소 재정의

# %% [markdown]
# ### 스케일링 플롯 요소

# %% [markdown]
# ## 컬러 팔레트 선택

# %% [markdown]
# ### 질적 색상 팔레트

# %% [markdown]
# #### 원형 컬러 시스템 사용

# %% [markdown]
# #### 범주형 컬러 브루어 팔레트 사용

# %% [markdown]
# #### xkcd 색상 측량에서 정의된 색상 사용
#
# * xkcd 색상표: https://xkcd.com/color/rgb/

# %% [markdown]
# ### 순차 색상 팔레트

# %% [markdown]
# #### 순차적 입방체 팔레트

# %% [markdown]
# #### 사용자 정의 순차적 팔레트

# %% [markdown]
# ### 색상 팔레트 나누기

# %% [markdown]
# #### 커스텀 분기 팔레트

# %% [markdown]
# ### 기본 색상 표 설정
