# %% [markdown]
# # 추측 통계의 기본
#
# - 추측통계: 일부 데이터로 전체의 통계적 성질을 추측

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 모집단과 표본
#
#
# - 모집단(population)
#     - 조사 대상이 되는 관측 가능한 개체로 된 집단 전체(관심있는 집단)
#
#
# - 표본(sample)
#     - 모집단에서 선택된 모집단 구성단위의 일부

# %% [markdown]
# ![%EB%AA%A8%EC%A7%91%EB%8B%A8%EA%B3%BC%ED%91%9C%EB%B3%B8.jpg](attachment:%EB%AA%A8%EC%A7%91%EB%8B%A8%EA%B3%BC%ED%91%9C%EB%B3%B8.jpg)

# %% [markdown]
# ### 표본의 추출 방법
# - 무작위 추출(임의 추출);임의로 표본을 추출하는 방법
# - 복원 추출:여러 차례 동일한 표본이 선택될 수있는 방법
# - 비복원 추출:동일한 표본은 한 번만 선택되는 방법

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %precision 3
# %matplotlib inline

# %%
df = pd.read_csv('C:/Users\Administrator/Desktop/coding/python/muticam/jupyter note/data/data//ch4_scores400.csv')
scores = np.array(df['score'])
scores[:10]
# Out:
# array([76, 55, 80, 80, 74, 61, 81, 76, 23, 80], dtype=int64)

# %%
# 복원 추출

np.random.choice([1,2,3],3)
# Out:
# array([1, 1, 1])

# %%
# 비복원 추출

np.random.choice([1,2,3],3, replace=False)
# Out:
# array([3, 1, 2])

# %%
np.random.seed(0)       # 매번 동일한 랜덤값을 얻기위해 기본 값 설정
np.random.choice([1,2,3],3)
# Out:
# array([1, 2, 1])

# %% [markdown]
# - 모집단(scores)에서 sample 추출

# %%
np.random.seed(0)
sample = np.random.choice(scores, 20)

# 표본 평균
sample.mean()
# Out:
# 70.4

# %%
# 전체 데이터의 평균
scores.mean()
# Out:
# 69.53

# %%
for i in range(5):
    sample = np.random.choice(scores, 20)
    print(f'{i+1}번째 무작위 추출로 얻은 표본평균', sample.mean())
# Out:
# 1번째 무작위 추출로 얻은 표본평균 72.45
# 2번째 무작위 추출로 얻은 표본평균 63.7
# 3번째 무작위 추출로 얻은 표본평균 66.05
# 4번째 무작위 추출로 얻은 표본평균 71.7
# 5번째 무작위 추출로 얻은 표본평균 74.15
