# %%
import numpy as np
from scipy.stats import *
import pandas as pd

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity="all"

# %% [markdown]
# ## 데이터가 얼마나 퍼져있는지:변이 통계량
#
#
# - 데이터들이 얼마나 흩어져 잇는가를 나타내는 것(산포도)
# - 하나의 수치로 데이터가 흩어진 정도를 계산해서 표현
# - 대표값과 더불어 데이터를 비교하는 경우에 유용하게 사용
# - EX) 평균이 같은 A집단과 B집단의 성적; 두 집단이 동일한 집단?

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - 어느 대학에서 같은 과목을 두 교수가 가르친다고 하자.두 교수 모두 평균 C학점을 학생들에게 준다면 그 과목을 배우려는 학생들은 어떤 교수를 선택해도 마찬가지라고 생각할 것이다.
# - 그러나 한 교수는 대부분의 학생들이 평범하다고 생각하여 C만 주고 다른 교수는 학생들이 반은 우수하고 반은 공부를 안 한다고 생각하여 A를 주거나 D-만 준다.
# - 그러므로 이러한 흩어짐의 정보 없이 학생들이 평균 성적 C라는 사실만 가지고 교수를 선택한다면 학점 때문에 어려움에 처할 수도 있게 된다.

# %% [markdown]
# #### 범위(range)
#
# - 데이터의 최대값과 최소값의 차이
# - 데이터가 퍼져 있는 정도를 나타내는 가장 간단한 방법
# - 범위가 클수록 산포가 크다고 말할 수 있지만
# - 중앙값과 마찬가지로 극단적인 값에 영향을 받음
# - 데이터 중 2개의 정보(최대값, 최소값)만을 이용하므로 적절한 척도로 사용하기 어려움
#
# **범위(R)=최댓값 - 최솟값**

# %% [markdown]
# #### 중간범위
# - 최대값과 최소값의 평균

# %% [markdown]
# #### 사분위간 범위 (interquartile range: IQR)
#
# - 데이터를 크기순서로 나열한 다음, 개수로 4등분할 때 첫 번째 사분위수(Q1:1사분위수, 25%지점)와 세 번째 사분위수(Q3:3사분위수, 75%지점)의 차이

# %% [markdown]
# #### 사분위수 편차(QUARTILE deviation)
# - 범위의 문제점을 보완한 척도
# - 사분위간 범위의 값을 2로 나눈 값으로 사분위 범위의 평균 값

# %% [markdown]
# ![%EC%82%AC%EB%B6%84%EC%9C%84%EC%88%98%ED%8E%B8%EC%B0%A8.PNG](attachment:%EC%82%AC%EB%B6%84%EC%9C%84%EC%88%98%ED%8E%B8%EC%B0%A8.PNG)

# %% [markdown]
# ### 분산(variance)
#
# - 산포도의 척도로 가장 널리 사용되는 방법
# - 데이터가 퍼져있는 정도의 기준으로 평균을 사용
#
#
# - 계산 방법
#     - 각 데이터와 평균의 차이를 제곱하여 합한 값의 평균

# %% [markdown]
# ![%EB%B6%84%EC%82%B0%EC%8B%9D.PNG](attachment:%EB%B6%84%EC%82%B0%EC%8B%9D.PNG)

# %% [markdown]
# - 데이터가 모집단 전체일 경우에는 데이터의 개수(n)으로 나누어 줌
# - 표본일 경우 (n-1)로 나누어 줌
# - 표본의 경우 n으로 나누어 주는 것보다 (n-1)로 나누어 주는 것이 더 좋은 척도가 되기
# 때문인데 표본의 크기가 큰 경우에는 별 차이가 없음

# %% [markdown]
# - 분산계산 : var(data, ddof=0|1) 함수 사용: ddof 생략하면 0  (표준편차식에서 분모가 n이라는 뜻)
# #### 자유도(ddof)를 1로 두는게 일반적임....(표준편차식에서 분모가 n-1 로 두는편임

# %%
## ddof인수 :  (자유도-모수집단냐 표본이냐)는 값을 1로 두고 사용한다고 생각하면 편함
## 특별한 경우 제외하고는 모두 sample 데이터이므로 분모를 n-1로 둠
## 즉 , ddof는 1로 둔다

# %%
x=[1,2,3,4,5]

np.var(x,ddof=1)  # 분모 n-1
np.var(x)         # 분모:n
np.array(x).var()
pd.Series(x).var(ddof=0)



# 값의 스케일에 크게 영향을 받으므로 
# 변수를 스케일링 한 후 분산
#  혹은 표준편차를 활용
# Out:
# 2.5
# 2.0
# 2.0
# 2.0

# %% [markdown]
# ### 표준편차(standard deviation)
#
# - 계산된 분산의 제곱급으로 계산
# - 평균을 중심으로 일정한 거리에 포함된 데이터의 비율이 얼마인가를 계산
# - 모든 데이터를 고려한 척도
# - 특징
#     - 모든 데이터가 동일한 값을 갖는다면 분산과 표준편차는 0으로 계산
#     - 모든 데이터에 동일한 값을 더해 주거나 빼도 변하지 않음
#     - 모든 데이터에 동일한 값(C)을 곱하면 분산은 $분산×C^2$으로 표준편차는 $표준편차×C$ 만큼 커짐

# %% [markdown]
# ![%EB%B6%84%EC%82%B0%ED%91%9C%EC%A4%80%ED%8E%B8%EC%B0%A8%EC%98%88%EC%8B%9C.PNG](attachment:%EB%B6%84%EC%82%B0%ED%91%9C%EC%A4%80%ED%8E%B8%EC%B0%A8%EC%98%88%EC%8B%9C.PNG)

# %% [markdown]
# #### 표준편차 계산: std() 함수 사용
#     - 분산에서 제곱의 영향을 없앤 지표
#     - 분산과 표준편차가 크면 클수록 산포가 크다

# %%
x=[1,2,3,4,5]


np.std(x,ddof=1)
np.array(x).std(ddof=0)
pd.Series(x).std(ddof=1)
# Out:
# 1.5811388300841898
# 1.4142135623730951
# 1.5811388300841898

# %% [markdown]
# #### 변동계수(CV: Coefficient of Variable)
#
# - 표본 표준편차를 표본 평균으로 나눈 값 또는 그 값에 100을 곱한 값
# - 상대 표준편차
# - 서로 다른 평균과 표준편차를 갖는 여러 데이터의 흩어진 정도를 비교 할 때 사용
#
# - 변동계수 값이 크다는 것은 데이터 흩어진 정도가 상대적으로 크다는 의미

# %% [markdown]
# - 표본 변동계수 $ 𝐶𝑉=\frac{S}{\overline{x}}$,  모변동계수  $𝐶𝑉= \frac{𝜎}{𝜇}$

# %% [markdown]
# ![%EB%B3%80%EB%8F%99%EA%B3%84%EC%88%98.png](attachment:%EB%B3%80%EB%8F%99%EA%B3%84%EC%88%98.png)

# %% [markdown]
# <!-- # #### 변동계수 계산 함수 : variation(data)
# # - 모든 계수가 양수가 아니면 잘 쓰이지 않음
# # - 자유도는 0으로 셋팅되어 있음 -->

# %% [markdown]
# #### 변동계수 계산 함수 : variation(data)
# - 모든 계수가 양수가 아니면 잘 쓰이지 않음
# - 자유도는 0으로 셋팅되어 있음

# %% [markdown]
# #### 변동계수의 필요성
#
# - 표준편차를 구할 때 스케일에 영향 받지 않기 위해서 변수 스케일링을 한 후 편차를 구함
#     - 데이터가 모두 양수인 경우 변동계수 사용

# %%
x1 = np.array([1,2,3,4,5])
x2 = x1 * 10
x2
# Out:
# array([10, 20, 30, 40, 50])

# %%
np.std(x1, ddof=1)
np.std(x2, ddof=1) # 표준편차는 * 10 만큼 차이가 남
# Out:
# 1.5811388300841898
# 15.811388300841896

# %%
# 변동계수는 동일함
variation(x1)
variation(x2)
# Out:
# 0.47140452079103173
# 0.4714045207910317

# %%
# 변동계수 수식

np.std(x1, ddof=1)/np.mean(x1)
np.std(x2, ddof=1)/np.mean(x2)
# Out:
# 0.5270462766947299
# 0.5270462766947299

# %% [markdown]
# #### 스케일링 (표준화)
#
# - 평균 : 0으로 표준편차 : 1 이 됨
# - 각 값들을 상대적인 값으로 변화시키는 기법
# - 평균이 95점(국어), 30점(수학) 인 반에서
#     - 길동이가 받은 취득점수 90점(국어), 80점(수학) 이라면 길동이는 어떤 과목을 더 잘한건가?
#
# - 표준화된 데이터는 점수와 같은 단위를 사용하지 않는다

# %%
x1
x2


# - standard scaling : 평균이 0 표준편차 1
# Out:
# array([1, 2, 3, 4, 5])
# array([10, 20, 30, 40, 50])

# %%
z1 = (x1- x1.mean())/x1.std()
z2 = (x2- x2.mean())/x2.std()

z1
z2 
# 보통 -3 ~ +3까지 분포 됨
# Out:
# array([-1.41421356, -0.70710678,  0.        ,  0.70710678,  1.41421356])
# array([-1.41421356, -0.70710678,  0.        ,  0.70710678,  1.41421356])

# %%
z1.mean()
z2.mean()
z1.std(ddof=0)
# Out:
# 0.0
# 0.0
# 0.9999999999999999

# %% [markdown]
# - MinMax 스케일링

# %%
z1 = (x1 - x1.min()) / (x1.max() - x1.min())
z2 = (x2 - x2.min()) / (x2.max() - x2.min())

x1
x2
print(z1)
print(z2)
# Out:
# array([1, 2, 3, 4, 5])
# array([10, 20, 30, 40, 50])
# [0.   0.25 0.5  0.75 1.  ]
# [0.   0.25 0.5  0.75 1.  ]

# %% [markdown]
# # 표준화 예제

# %%
df = pd.read_csv('C:/Users\Administrator/Desktop/coding/python/muticam/jupyter note/data/data/ch2_scores_em.csv',
                 index_col='student number')
# df의 처음 5행을 표시
df.head()
# Out:
#                 english  mathematics
# student number
# 1                    42           65
# 2                    69           80
# 3                    56           63
# 4                    41           63
# 5                    57           76

# %%
scores = df.loc[1:10]
scores.index=['A', 'B', 'C', 'D', 'E','F', 'G', 'H', 'I', 'J']
scores.index.name='students'

# %%
scores
scores.mean()
scores.std()
# Out:
#           english  mathematics
# students
# A              42           65
# B              69           80
# C              56           63
# D              41           63
# E              57           76
# F              48           60
# G              65           81
# H              49           66
# I              65           78
# J              58           82
# english        55.0
# mathematics    71.4
# dtype: float64
# english        9.775252
# mathematics    8.720347
# dtype: float64

# %%
# np.set_printoptions(precision=20, suppress=True)
# pd.options.display.float_format = '{:.2f}'.format
# import numpy as np
# # numpy float 출력옵션 변경
# np.set_printoptions(precision=3)

import numpy as np
# numpy float 출력옵션 변경
np.set_printoptions(formatter={'float_kind': lambda x: "{0:0.3f}".format(x)})

# %%
em_z=(scores['english']-scores['english'].mean())/scores['english'].std()
mt_z=(scores['mathematics']-scores['mathematics'].mean())/scores['mathematics'].std()
em_z
mt_z
# Out:
# students
# A   -1.329889
# B    1.432188
# C    0.102299
# D   -1.432188
# E    0.204598
# F   -0.716094
# G    1.022992
# H   -0.613795
# I    1.022992
# J    0.306897
# Name: english, dtype: float64
# students
# A   -0.733916
# B    0.986199
# C   -0.963264
# D   -0.963264
# E    0.527502
# F   -1.307287
# G    1.100874
# H   -0.619241
# I    0.756851
# J    1.215548
# Name: mathematics, dtype: float64

# %%
em_z.mean()
mt_z.mean()
em_z.std()
mt_z.std()
# Out:
# 2.7755575615628914e-17
# -6.883382752675971e-16
# 1.0
# 1.0

# %% [markdown]
# 표준정규화 작업은 워낙 많이 사용하다보니 일종의 패키지가 구성되어있다.

# %% [markdown]
# ### sklearn을 이용한 스케일링 - 머신러닝을위해 쓰는 경우가 대부분
# - df의 각 열에 대해서 스케일링하는데 적합함

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
X = pd.DataFrame({"X1":[1, 2, 3, 4, 5],
    "X2": [10, 20, 30, 40, 50]})

X
# Out:
#    X1  X2
# 0   1  10
# 1   2  20
# 2   3  30
# 3   4  40
# 4   5  50

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler() # 생성자 함수 이용해 객체 인스턴스 생성
Z= scaler.fit_transform(X) # ndarray로 결과 반환
pd.DataFrame(Z)
# Out:
#       0     1
# 0  0.00  0.00
# 1  0.25  0.25
# 2  0.50  0.50
# 3  0.75  0.75
# 4  1.00  1.00

# %% [markdown]
# ### 편찻값
# - 학력 등의 검사 결과가 집단의 평균값에서 어느 정도 떨어져 잇는가를 수치로 나태낸것, 편차를 표준 편차로 나눠 10배를 한 뒤 50을 더한 것임.
#
# - 평균을 50, 표준편차가 10이 되도록 정규화 한 값

# %%
z= 50 + 10* (scores-np.mean(scores))/np.std(scores)
z
z.mean()
z.std()
# Out:
#             english  mathematics
# students
# A         35.981739    42.263848
# B         65.096588    60.395454
# C         51.078328    39.846301
# D         34.903412    39.846301
# E         52.156655    55.560359
# F         42.451706    36.219980
# G         60.783277    61.604227
# H         43.530034    43.472622
# I         60.783277    57.977906
# J         53.234983    62.813001
# english        50.0
# mathematics    50.0
# dtype: float64
# english        10.540926
# mathematics    10.540926
# dtype: float64

# %%
result=pd.concat([scores,z], axis=1)
result.columns=['영어','수학','영어편찻값','수학편찻값']
result[['영어','영어편찻값','수학','수학편찻값']]
# Out:
#           영어      영어편찻값  수학      수학편찻값
# students
# A         42  35.981739  65  42.263848
# B         69  65.096588  80  60.395454
# C         56  51.078328  63  39.846301
# D         41  34.903412  63  39.846301
# E         57  52.156655  76  55.560359
# F         48  42.451706  60  36.219980
# G         65  60.783277  81  61.604227
# H         49  43.530034  66  43.472622
# I         65  60.783277  78  57.977906
# J         58  53.234983  82  62.813001
