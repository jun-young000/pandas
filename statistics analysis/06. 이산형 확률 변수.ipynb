# %% [markdown]
# # 확률 분포
#     - 확률변수가 어떻게 움직이는지를 나타낸 것

# %% [markdown]
# ### 확률 변수의 구분
#     - 이산 확률 변수: 변수가 취할 수 았는 값의 개수가 유한
#     - 연속 확률 변수: 변수가 취할 수 있는 값의 개수가 무한

# %% [markdown]
# ![%EC%9D%B4%EC%82%B0%EC%97%B0%EC%86%8D%ED%99%95%EB%A5%A0%EB%B3%80%EC%88%98.png](attachment:%EC%9D%B4%EC%82%B0%EC%97%B0%EC%86%8D%ED%99%95%EB%A5%A0%EB%B3%80%EC%88%98.png)

# %% [markdown]
# ### 확률함수
# - 확률변수 X가 특정 실수 값 x를 취할 확률을 X의 함수(f)로 나타낸 것
#     - 확률질량함수(probability mass function: pmf)
#         - 확률변수가 이산형인 경우
#     - 확률밀도함수(probability density function: pdf)
#         - 확률변수가 연속형인 경우

# %% [markdown]
# ### 확률 분포의 평균(mean)- 기대값

# %% [markdown]
# - 기대값((expected value)라고 함
# - 확률 변수의 기대값({E})은 각 사건이 벌어졌을 때의 이득과 그 사건이 벌어질 확률을 곱한 것을 전체 사건에 대해 합한 값이다.
#     - 어떤 확률적 사건에 대한 평균의 의미로 생각할 수 있다.
#
#     - E(X) 또는 μX 로 표시
#     - 이산확률분포의 기대값 : 확률을 가중값으로 사용한 가중평균
#     - 연속확률분포의 기대값 : 적분개념의 면적

# %% [markdown]
# ![%EA%B8%B0%EB%8C%80%EA%B0%92.png](attachment:%EA%B8%B0%EB%8C%80%EA%B0%92.png)

# %% [markdown]
# - 모평균
#     - 모 평균(population mean) μ는 모 집단의 평균이다. 모두 더한 후 전체 데이터 수 n으로 나눈다.

# %%
import numpy as np
import matplotlib.pyplot as plt

# %precision 3
# %matplotlib inline

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity="all"

# %% [markdown]
# #### 이산형 확률
# - 확률변수 x가 취할 수 있는 값의 집합 {x_1,x_2,x_3,......,x_k}
# - x가 x_k라는 값을 취하는 확률
#
#
# ![%EC%9D%B4%EC%82%B0%ED%99%95%EB%A5%A0.png](attachment:%EC%9D%B4%EC%82%B0%ED%99%95%EB%A5%A0.png)
#
# - 확률 질량함수(확률함수)-pmf

# %% [markdown]
# ![pmf.png](attachment:pmf.png)

# %% [markdown]
# ![%ED%91%9C4-2.jpg](attachment:%ED%91%9C4-2.jpg)

# %% [markdown]
# ![%EB%B6%88%EA%B3%B5%EC%A0%95%ED%95%9C%EC%A3%BC%EC%82%AC%EC%9C%84%ED%99%95%EB%A5%A0%EB%B3%80%EC%88%98.PNG](attachment:%EB%B6%88%EA%B3%B5%EC%A0%95%ED%95%9C%EC%A3%BC%EC%82%AC%EC%9C%84%ED%99%95%EB%A5%A0%EB%B3%80%EC%88%98.PNG)

# %%
# 위 식을 함수로 구현

# %%
def f(x):
    if x in x_set:
        return x/21
    else:
        return 0

# %%
# 확률 변수가 취할 수 있는 값의 set
x_set=np.array([1,2,3,4,5,6])

# %%
# 확률변수 x
x=[x_set,f] # 확률분포 [x_set,f]에 의해 확률변수 x의 동작이 결정됨

# %%
#확률 p_k를 구한다
prob=np.array([f(x_k) for x_k in x_set ])
x_set
prob
# x_k 와 p_k의 대응을 사전식으로 표시
zip(x_set,prob)

dict(zip(x_set,prob))
# Out:
# array([1, 2, 3, 4, 5, 6])
# array([0.048, 0.095, 0.143, 0.19 , 0.238, 0.286])
# {1: 0.047619047619047616,
#  2: 0.09523809523809523,
#  3: 0.14285714285714285,
#  4: 0.19047619047619047,
#  5: 0.23809523809523808,
#  6: 0.2857142857142857}

# %% [markdown]
# ![%ED%91%9C4-2.jpg](attachment:%ED%91%9C4-2.jpg)

# %%
### 이산형 확률분포 그래프
fig=plt.figure(figsize=(10,16))
ax=fig.add_subplot(111)
ax.bar(x_set,prob)

ax.set_xlabel('value')
ax.set_ylabel('probability')

plt.show()
# Out:
# <BarContainer object of 6 artists>
# Text(0.5, 0, 'value')
# Text(0, 0.5, 'probability')

# %% [markdown]
# ![%EC%9D%B4%EC%82%B0%ED%99%95%EB%A5%A0%EC%84%B1%EC%A7%88.png](attachment:%EC%9D%B4%EC%82%B0%ED%99%95%EB%A5%A0%EC%84%B1%EC%A7%88.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![%EC%9D%B4%EC%82%B0%EB%88%84%EC%A0%81.png](attachment:%EC%9D%B4%EC%82%B0%EB%88%84%EC%A0%81.png)

# %%
# 작거나 같은 이므로 주어진 x보다 작거나 같은 동안의 확률을 모두 더함-f(x) 확률함수

def F(x):
    return np.sum([f(x_k) for x_k in x_set if x_k <=x ])

# %%
# 주사위의 눈이 3이하가 될 확률
F(3)  #  x_set 의 원소값이 3보다 작거나 같을떄까지의 확률의 합계
f(x)  #  x_set 의 원소값이 3일떄 확률
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-1ec9dc059742> in <module>
#       1 # 주사위의 눈이 3이하가 될 확률
# ----> 2 F(3)  #  x_set 의 원소값이 3보다 작거나 같을떄까지의 확률의 합계
#       3 f(x)  #  x_set 의 원소값이 3일떄 확률
#
# <ipython-input-7-e5acd64fb874> in F(x)
#       2
#       3 def F(x):
# ----> 4     return np.sum([f(x_k) for x_k in x_set if x_k <=x ])
#
# NameError: name 'x_set' is not defined

# %% [markdown]
# ### 확률변수의 변환
#
#
# - 확률 변수에 연산을 적용시켜 변화시킨다고 가정=> 새로운 데이터 집합=>확률변수가 됨
#
# - 확률 변수의 변환 연산: 2x+3
#
# - 위 연산을 적용시켜 변환된 확률 변수를 y라고 한다면

# %%
y_set=np.array([2*x_k + 3 for x_k in x_set])

prob=np.array([f(x_k)for x_k in x_set])


dict(zip(y_set, prob))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-6de682bcbac5> in <module>
# ----> 1 y_set=np.array([2*x_k + 3 for x_k in x_set])
#       2
#       3 prob=np.array([f(x_k)for x_k in x_set])
#       4
#       5
#
# NameError: name 'x_set' is not defined

# %% [markdown]
# # 1차원 이산형 확률변수의 지표

# %% [markdown]
# - 평균:기댓값
#     - 확률변수를 무제한 시행하여 얻은 실험값의 합산

# %% [markdown]
# ![%EA%B8%B0%EB%8C%80%EA%B0%921.png](attachment:%EA%B8%B0%EB%8C%80%EA%B0%921.png)

# %% [markdown]
# - 수식을 함수로 구현

# %% [markdown]
# ![%EA%B8%B0%EB%8C%80%EA%B0%92%ED%95%A8%EC%88%98%EA%B5%AC%ED%98%84.png](attachment:%EA%B8%B0%EB%8C%80%EA%B0%92%ED%95%A8%EC%88%98%EA%B5%AC%ED%98%84.png)

# %% [markdown]
# - 인수 g가 확률변수에 대한 연산을 구현한 함수
#     - g에 아무것도 지정하지 않으면 확률변수 x의 기댓값이 구해짐

# %%
#  불공정 주사위 확률에 대한 기대값

x
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-e9ce664c3435> in <module>
#       1 #  불공정 주사위 확률에 대한 기대값
#       2
# ----> 3 x
#
# NameError: name 'x' is not defined

# %% [markdown]
# ### 분산
# - 확률 변수의 각 값에서 기대값ㅇㄹ 뺀 편차의 제곱을 계산한후 기대값으로 계산

# %% [markdown]
# ![%EC%9D%B4%EC%82%B0%EB%B6%84%EC%82%B0.png](attachment:%EC%9D%B4%EC%82%B0%EB%B6%84%EC%82%B0.png)

# %% [markdown]
# ### 불공정한 주사위의 분산

# %%
### 불공정한 주사위의 기대값 함수 E(X)


mean= E(X)
np.sum([(x_k-mean)**2*f(x_k) for x_k in  x_set] )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-eb98f82d341a> in <module>
#       2
#       3
# ----> 4 mean= E(X)
#       5 np.sum([(x_k-mean)**2*f(x_k) for x_k in  x_set] )
#
# NameError: name 'E' is not defined

# %%
def v(x,g=1amda x: x):
    x_set, f = x
    mean= E(x)
    return np.sum([ (g(x_k)-mean])

# %%
v(x)

# %% [markdown]
# - 확률 변수 x 대한 변환변수 2x+3에 대한 분산 계산

# %% [markdown]
# ![image.png](attachment:image.png)
